# %% [markdown]
# <a href="https://colab.research.google.com/github/dinisrferreira/Pseudodiagnosticity-in-a-continuous-learning-environment-Reis-2020-/blob/main/DiagnosticNet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn
import pandas as pd
import torch.optim as optim
from torch.optim.lr_scheduler import ReduceLROnPlateau
from torch.utils.data import DataLoader, TensorDataset
import random

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Load data from Google Drive
folder_path = '/content/drive/My Drive/Data for DiagnosticNet/'
wicked_train_set = pd.read_csv(f'{folder_path}wicked_train_set_20240801_214722.csv')
wicked_test_set = pd.read_csv(f'{folder_path}wicked_test_set_20240801_214722.csv')
kind_train_set = pd.read_csv(f'{folder_path}kind_train_set_20240801_214722.csv')
kind_test_set = pd.read_csv(f'{folder_path}kind_test_set_20240801_214722.csv')

# %%
def prepare_data(df):
    X = df['input'].apply(eval).values.tolist()
    full_values = df['full_values'].apply(eval).values.tolist()
    y = df['label'].values
    initial_choices = df['initial_choice'].values  # Get initial choices from the DataFrame
    golden_labels = df['golden_label'].apply(eval).values.tolist()

    X_tensor = torch.tensor(X, dtype=torch.float32)
    full_values_tensor = torch.tensor(full_values, dtype=torch.float32)
    y_tensor = torch.tensor(y, dtype=torch.long)
    initial_choices_tensor = torch.tensor(initial_choices, dtype=torch.long)  # Convert to tensor
    golden_labels_tensor = torch.tensor(golden_labels, dtype=torch.float32)  # Convert to tensor

    return TensorDataset(X_tensor, full_values_tensor, y_tensor, initial_choices_tensor, golden_labels_tensor)  # Include golden_labels in the TensorDataset

# %%
train_data_wicked = prepare_data(wicked_train_set)
test_data_wicked = prepare_data(wicked_test_set)
train_data_kind = prepare_data(kind_train_set)
test_data_kind = prepare_data(kind_test_set)

batch_size = 32
train_loader_wicked = DataLoader(train_data_wicked, batch_size=batch_size, shuffle=True)
test_loader_wicked = DataLoader(test_data_wicked, batch_size=batch_size, shuffle=False)
train_loader_kind = DataLoader(train_data_kind, batch_size=batch_size, shuffle=True)
test_loader_kind = DataLoader(test_data_kind, batch_size=batch_size, shuffle=False)

# %%
class DiagnosticNet(nn.Module):
    def __init__(self):
        super(DiagnosticNet, self).__init__()
        self.fc1 = nn.Linear(4, 10)
        self.fc2 = nn.Linear(10, 4)  # Output 4 probabilities, one for each cell

    def forward(self, x, initial_choices):
        x = torch.relu(self.fc1(x))
        logits = self.fc2(x)

        # Create a mask to zero out the probability of the initial cell
        mask = torch.ones_like(logits)
        for i, initial_choice in enumerate(initial_choices):
            mask[i, initial_choice] = 0

        masked_logits = logits * mask
        # Apply softmax to get probability distribution
        probs = torch.softmax(masked_logits, dim=1)

        return probs

# %%
def determine_strategy(initial_choice, second_choice):
    row_initial, col_initial = divmod(initial_choice, 2)
    row_second, col_second = divmod(second_choice, 2)

    if row_initial == row_second:
        return 'row'
    elif col_initial == col_second:
        return 'column'
    else:
        return 'diagonal'

# %%
# Define the loss function
criterion = nn.KLDivLoss(reduction='batchmean')

# %%
def train_model(model, train_loader, criterion, optimizer, num_epochs=50):
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        strategy_counts = {'row': 0, 'column': 0, 'diagonal': 0}

        for inputs, full_values, labels, initial_choices, golden_labels in train_loader:
            optimizer.zero_grad()
            outputs = model(inputs, initial_choices)

            # Compute the loss using KLDivLoss
            loss = criterion(outputs.log(), golden_labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

            # Track strategy usage
            _, predicted_choices = torch.max(outputs, 1)
            for i in range(len(inputs)):
                initial_choice = initial_choices[i].item()
                second_choice = predicted_choices[i].item()
                chosen_strategy = determine_strategy(initial_choice, second_choice)
                strategy_counts[chosen_strategy] += 1

        avg_loss = running_loss / len(train_loader)

        print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {avg_loss:.4f}")
        print(f"Strategy usage - Row: {strategy_counts['row']}, Column: {strategy_counts['column']}, Diagonal: {strategy_counts['diagonal']}")
        print('-' * 50)

# %%
# Instantiate the model, optimizer, and scheduler
model = DiagnosticNet()
optimizer = optim.Adam(model.parameters(), lr=0.001)
scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=5, verbose=True)

# %% [markdown]
# Por alguma razão escolhas diagonais acontecem imenso no ambiente wicked (pode ser algo relacionado com os dados idk). No ambiente kind pelo menos descem at some point. Compreensivelmente a loss começa baixa no wicked por isso tenho de evitar aprendizagem muito rápida.

# %%
# Train the model for wicked and kind environments
print("Training on wicked environment:")
train_model(model, train_loader_wicked, criterion, optimizer, num_epochs=50)
print
print("Training on kind environment:")
train_model(model, train_loader_kind, criterion, optimizer, num_epochs=50)
# Out:
# Training on wicked environment:
# Epoch [1/50], Loss: 0.6865
# Strategy usage - Row: 208, Column: 398, Diagonal: 194
# --------------------------------------------------
# Epoch [2/50], Loss: 0.6744
# Strategy usage - Row: 70, Column: 364, Diagonal: 366
# --------------------------------------------------
# Epoch [3/50], Loss: 0.6619
# Strategy usage - Row: 185, Column: 308, Diagonal: 307
# --------------------------------------------------
# Epoch [4/50], Loss: 0.6490
# Strategy usage - Row: 267, Column: 200, Diagonal: 333
# --------------------------------------------------
# Epoch [5/50], Loss: 0.6346
# Strategy usage - Row: 359, Column: 105, Diagonal: 336
# --------------------------------------------------
# Epoch [6/50], Loss: 0.6179
# Strategy usage - Row: 371, Column: 76, Diagonal: 353
# --------------------------------------------------
# Epoch [7/50], Loss: 0.5986
# Strategy usage - Row: 371, Column: 61, Diagonal: 368
# --------------------------------------------------
# Epoch [8/50], Loss: 0.5781
# Strategy usage - Row: 371, Column: 35, Diagonal: 394
# --------------------------------------------------
# Epoch [9/50], Loss: 0.5576
# Strategy usage - Row: 371, Column: 27, Diagonal: 402
# --------------------------------------------------
# Epoch [10/50], Loss: 0.5345
# Strategy usage - Row: 371, Column: 6, Diagonal: 423
# --------------------------------------------------
# Epoch [11/50], Loss: 0.5118
# Strategy usage - Row: 371, Column: 0, Diagonal: 429
# --------------------------------------------------
# Epoch [12/50], Loss: 0.4890
# Strategy usage - Row: 371, Column: 0, Diagonal: 429
# --------------------------------------------------
# Epoch [13/50], Loss: 0.4661
# Strategy usage - Row: 371, Column: 0, Diagonal: 429
# --------------------------------------------------
# Epoch [14/50], Loss: 0.4412
# Strategy usage - Row: 371, Column: 0, Diagonal: 429
# --------------------------------------------------
# Epoch [15/50], Loss: 0.4156
# Strategy usage - Row: 371, Column: 0, Diagonal: 429
# --------------------------------------------------
# Epoch [16/50], Loss: 0.3909
# Strategy usage - Row: 371, Column: 0, Diagonal: 429
# --------------------------------------------------
# Epoch [17/50], Loss: 0.3680
# Strategy usage - Row: 371, Column: 0, Diagonal: 429
# --------------------------------------------------
# Epoch [18/50], Loss: 0.3468
# Strategy usage - Row: 366, Column: 5, Diagonal: 429
# --------------------------------------------------
# Epoch [19/50], Loss: 0.3271
# Strategy usage - Row: 350, Column: 21, Diagonal: 429
# --------------------------------------------------
# Epoch [20/50], Loss: 0.3090
# Strategy usage - Row: 337, Column: 34, Diagonal: 429
# --------------------------------------------------
# Epoch [21/50], Loss: 0.2923
# Strategy usage - Row: 335, Column: 36, Diagonal: 429
# --------------------------------------------------
# Epoch [22/50], Loss: 0.2771
# Strategy usage - Row: 332, Column: 42, Diagonal: 426
# --------------------------------------------------
# Epoch [23/50], Loss: 0.2629
# Strategy usage - Row: 347, Column: 44, Diagonal: 409
# --------------------------------------------------
# Epoch [24/50], Loss: 0.2503
# Strategy usage - Row: 386, Column: 14, Diagonal: 400
# --------------------------------------------------
# Epoch [25/50], Loss: 0.2385
# Strategy usage - Row: 401, Column: 5, Diagonal: 394
# --------------------------------------------------
# Epoch [26/50], Loss: 0.2280
# Strategy usage - Row: 419, Column: 6, Diagonal: 375
# --------------------------------------------------
# Epoch [27/50], Loss: 0.2182
# Strategy usage - Row: 404, Column: 26, Diagonal: 370
# --------------------------------------------------
# Epoch [28/50], Loss: 0.2094
# Strategy usage - Row: 394, Column: 51, Diagonal: 355
# --------------------------------------------------
# Epoch [29/50], Loss: 0.2012
# Strategy usage - Row: 370, Column: 92, Diagonal: 338
# --------------------------------------------------
# Epoch [30/50], Loss: 0.1940
# Strategy usage - Row: 366, Column: 96, Diagonal: 338
# --------------------------------------------------
# Epoch [31/50], Loss: 0.1871
# Strategy usage - Row: 360, Column: 106, Diagonal: 334
# --------------------------------------------------
# Epoch [32/50], Loss: 0.1810
# Strategy usage - Row: 347, Column: 128, Diagonal: 325
# --------------------------------------------------
# Epoch [33/50], Loss: 0.1752
# Strategy usage - Row: 348, Column: 132, Diagonal: 320
# --------------------------------------------------
# Epoch [34/50], Loss: 0.1701
# Strategy usage - Row: 356, Column: 123, Diagonal: 321
# --------------------------------------------------
# Epoch [35/50], Loss: 0.1652
# Strategy usage - Row: 352, Column: 128, Diagonal: 320
# --------------------------------------------------
# Epoch [36/50], Loss: 0.1608
# Strategy usage - Row: 338, Column: 145, Diagonal: 317
# --------------------------------------------------
# Epoch [37/50], Loss: 0.1567
# Strategy usage - Row: 337, Column: 144, Diagonal: 319
# --------------------------------------------------
# Epoch [38/50], Loss: 0.1529
# Strategy usage - Row: 347, Column: 144, Diagonal: 309
# --------------------------------------------------
# Epoch [39/50], Loss: 0.1494
# Strategy usage - Row: 349, Column: 142, Diagonal: 309
# --------------------------------------------------
# Epoch [40/50], Loss: 0.1461
# Strategy usage - Row: 348, Column: 144, Diagonal: 308
# --------------------------------------------------
# Epoch [41/50], Loss: 0.1430
# Strategy usage - Row: 352, Column: 148, Diagonal: 300
# --------------------------------------------------
# Epoch [42/50], Loss: 0.1403
# Strategy usage - Row: 356, Column: 146, Diagonal: 298
# --------------------------------------------------
# Epoch [43/50], Loss: 0.1376
# Strategy usage - Row: 350, Column: 151, Diagonal: 299
# --------------------------------------------------
# Epoch [44/50], Loss: 0.1351
# Strategy usage - Row: 362, Column: 152, Diagonal: 286
# --------------------------------------------------
# Epoch [45/50], Loss: 0.1329
# Strategy usage - Row: 366, Column: 149, Diagonal: 285
# --------------------------------------------------
# Epoch [46/50], Loss: 0.1308
# Strategy usage - Row: 370, Column: 150, Diagonal: 280
# --------------------------------------------------
# Epoch [47/50], Loss: 0.1288
# Strategy usage - Row: 374, Column: 149, Diagonal: 277
# --------------------------------------------------
# Epoch [48/50], Loss: 0.1269
# Strategy usage - Row: 379, Column: 152, Diagonal: 269
# --------------------------------------------------
# Epoch [49/50], Loss: 0.1254
# Strategy usage - Row: 380, Column: 150, Diagonal: 270
# --------------------------------------------------
# Epoch [50/50], Loss: 0.1237
# Strategy usage - Row: 381, Column: 149, Diagonal: 270
# --------------------------------------------------
# Training on kind environment:
# Epoch [1/50], Loss: 1.1842
# Strategy usage - Row: 553, Column: 53, Diagonal: 194
# --------------------------------------------------
# Epoch [2/50], Loss: 0.9993
# Strategy usage - Row: 657, Column: 0, Diagonal: 143
# --------------------------------------------------
# Epoch [3/50], Loss: 0.8846
# Strategy usage - Row: 673, Column: 0, Diagonal: 127
# --------------------------------------------------
# Epoch [4/50], Loss: 0.8121
# Strategy usage - Row: 686, Column: 1, Diagonal: 113
# --------------------------------------------------
# Epoch [5/50], Loss: 0.7606
# Strategy usage - Row: 692, Column: 4, Diagonal: 104
# --------------------------------------------------
# Epoch [6/50], Loss: 0.7204
# Strategy usage - Row: 698, Column: 3, Diagonal: 99
# --------------------------------------------------
# Epoch [7/50], Loss: 0.6897
# Strategy usage - Row: 701, Column: 0, Diagonal: 99
# --------------------------------------------------
# Epoch [8/50], Loss: 0.6643
# Strategy usage - Row: 698, Column: 3, Diagonal: 99
# --------------------------------------------------
# Epoch [9/50], Loss: 0.6439
# Strategy usage - Row: 698, Column: 3, Diagonal: 99
# --------------------------------------------------
# Epoch [10/50], Loss: 0.6267
# Strategy usage - Row: 698, Column: 3, Diagonal: 99
# --------------------------------------------------
# Epoch [11/50], Loss: 0.6121
# Strategy usage - Row: 696, Column: 5, Diagonal: 99
# --------------------------------------------------
# Epoch [12/50], Loss: 0.5993
# Strategy usage - Row: 696, Column: 5, Diagonal: 99
# --------------------------------------------------
# Epoch [13/50], Loss: 0.5884
# Strategy usage - Row: 696, Column: 5, Diagonal: 99
# --------------------------------------------------
# Epoch [14/50], Loss: 0.5792
# Strategy usage - Row: 693, Column: 8, Diagonal: 99
# --------------------------------------------------
# Epoch [15/50], Loss: 0.5706
# Strategy usage - Row: 694, Column: 7, Diagonal: 99
# --------------------------------------------------
# Epoch [16/50], Loss: 0.5636
# Strategy usage - Row: 695, Column: 9, Diagonal: 96
# --------------------------------------------------
# Epoch [17/50], Loss: 0.5572
# Strategy usage - Row: 698, Column: 9, Diagonal: 93
# --------------------------------------------------
# Epoch [18/50], Loss: 0.5520
# Strategy usage - Row: 705, Column: 9, Diagonal: 86
# --------------------------------------------------
# Epoch [19/50], Loss: 0.5475
# Strategy usage - Row: 710, Column: 9, Diagonal: 81
# --------------------------------------------------
# Epoch [20/50], Loss: 0.5434
# Strategy usage - Row: 718, Column: 9, Diagonal: 73
# --------------------------------------------------
# Epoch [21/50], Loss: 0.5400
# Strategy usage - Row: 719, Column: 9, Diagonal: 72
# --------------------------------------------------
# Epoch [22/50], Loss: 0.5367
# Strategy usage - Row: 719, Column: 9, Diagonal: 72
# --------------------------------------------------
# Epoch [23/50], Loss: 0.5337
# Strategy usage - Row: 719, Column: 9, Diagonal: 72
# --------------------------------------------------
# Epoch [24/50], Loss: 0.5316
# Strategy usage - Row: 726, Column: 9, Diagonal: 65
# --------------------------------------------------
# Epoch [25/50], Loss: 0.5289
# Strategy usage - Row: 730, Column: 9, Diagonal: 61
# --------------------------------------------------
# Epoch [26/50], Loss: 0.5269
# Strategy usage - Row: 727, Column: 9, Diagonal: 64
# --------------------------------------------------
# Epoch [27/50], Loss: 0.5253
# Strategy usage - Row: 744, Column: 9, Diagonal: 47
# --------------------------------------------------
# Epoch [28/50], Loss: 0.5233
# Strategy usage - Row: 738, Column: 9, Diagonal: 53
# --------------------------------------------------
# Epoch [29/50], Loss: 0.5216
# Strategy usage - Row: 764, Column: 9, Diagonal: 27
# --------------------------------------------------
# Epoch [30/50], Loss: 0.5204
# Strategy usage - Row: 791, Column: 9, Diagonal: 0
# --------------------------------------------------
# Epoch [31/50], Loss: 0.5194
# Strategy usage - Row: 781, Column: 9, Diagonal: 10
# --------------------------------------------------
# Epoch [32/50], Loss: 0.5174
# Strategy usage - Row: 791, Column: 9, Diagonal: 0
# --------------------------------------------------
# Epoch [33/50], Loss: 0.5162
# Strategy usage - Row: 791, Column: 9, Diagonal: 0
# --------------------------------------------------
# Epoch [34/50], Loss: 0.5153
# Strategy usage - Row: 791, Column: 9, Diagonal: 0
# --------------------------------------------------
# Epoch [35/50], Loss: 0.5139
# Strategy usage - Row: 789, Column: 8, Diagonal: 3
# --------------------------------------------------
# Epoch [36/50], Loss: 0.5128
# Strategy usage - Row: 791, Column: 9, Diagonal: 0
# --------------------------------------------------
# Epoch [37/50], Loss: 0.5118
# Strategy usage - Row: 791, Column: 9, Diagonal: 0
# --------------------------------------------------
# Epoch [38/50], Loss: 0.5109
# Strategy usage - Row: 791, Column: 9, Diagonal: 0
# --------------------------------------------------
# Epoch [39/50], Loss: 0.5101
# Strategy usage - Row: 791, Column: 9, Diagonal: 0
# --------------------------------------------------
# Epoch [40/50], Loss: 0.5090
# Strategy usage - Row: 791, Column: 9, Diagonal: 0
# --------------------------------------------------
# Epoch [41/50], Loss: 0.5079
# Strategy usage - Row: 791, Column: 9, Diagonal: 0
# --------------------------------------------------
# Epoch [42/50], Loss: 0.5071
# Strategy usage - Row: 795, Column: 5, Diagonal: 0
# --------------------------------------------------
# Epoch [43/50], Loss: 0.5063
# Strategy usage - Row: 792, Column: 8, Diagonal: 0
# --------------------------------------------------
# Epoch [44/50], Loss: 0.5055
# Strategy usage - Row: 794, Column: 5, Diagonal: 1
# --------------------------------------------------
# Epoch [45/50], Loss: 0.5047
# Strategy usage - Row: 795, Column: 5, Diagonal: 0
# --------------------------------------------------
# Epoch [46/50], Loss: 0.5039
# Strategy usage - Row: 795, Column: 5, Diagonal: 0
# --------------------------------------------------
# Epoch [47/50], Loss: 0.5033
# Strategy usage - Row: 795, Column: 5, Diagonal: 0
# --------------------------------------------------
# Epoch [48/50], Loss: 0.5027
# Strategy usage - Row: 795, Column: 5, Diagonal: 0
# --------------------------------------------------
# Epoch [49/50], Loss: 0.5022
# Strategy usage - Row: 795, Column: 5, Diagonal: 0
# --------------------------------------------------
# Epoch [50/50], Loss: 0.5013
# Strategy usage - Row: 795, Column: 5, Diagonal: 0
# --------------------------------------------------
